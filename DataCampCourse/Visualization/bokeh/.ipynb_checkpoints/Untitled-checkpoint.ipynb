# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import pandas as pd

#General Payment Data - Detailed Dataset 2013 Reporting Year
df = pd.read_json("https://openpaymentsdata.cms.gov/resource/tvyk-kca8.json")
df.head()
# Out:
#   applicable_manufacturer_or_applicable_gpo_making_payment_country  \
# 0                                      United States
# 1                                      United States
# 2                                      United States
# 3                                      United States
# 4                                      United States
#
#    applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 0                                       100000011034
# 1                                       100000000278
# 2                                       100000000144
# 3                                       100000000137
# 4                                       100000005490
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 0                               Aqua Pharmaceuticals
# 1                                      Allergan Inc.
# 2                                   Novo Nordisk Inc
# 3                             Astellas Pharma US Inc
# 4                                         Davol Inc.
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_state change_type  \
# 0                                                 PA               UNCHANGED
# 1                                                 NJ               UNCHANGED
# 2                                                 NJ               UNCHANGED
# 3                                                 IL               UNCHANGED
# 4                                                 RI               UNCHANGED
#
#   charity_indicator city_of_travel contextual_information country_of_travel  \
# 0                No            NaN                    NaN               NaN
# 1                No            NaN                    NaN               NaN
# 2                No            NaN                    NaN               NaN
# 3               NaN            NaN                    NaN               NaN
# 4               NaN            NaN                    NaN               NaN
#
#         covered_recipient_type                ...                 \
# 0  Covered Recipient Physician                ...
# 1  Covered Recipient Physician                ...
# 2  Covered Recipient Physician                ...
# 3  Covered Recipient Physician                ...
# 4  Covered Recipient Physician                ...
#
#   recipient_zip_code  record_id state_of_travel  \
# 0         48067-1835  105444892             NaN
# 1              32669  102534086             NaN
# 2              35661   32285789             NaN
# 3              73112  101672924             NaN
# 4              52403  101628054             NaN
#
#   submitting_applicable_manufacturer_or_applicable_gpo_name  \
# 0                               Aqua Pharmaceuticals
# 1                                      Allergan Inc.
# 2                                   Novo Nordisk Inc
# 3                             Astellas Pharma US Inc
# 4                    C. R. Bard, Inc. & Subsidiaries
#
#   teaching_hospital_ccn teaching_hospital_id teaching_hospital_name  \
# 0                   NaN                  NaN                    NaN
# 1                   NaN                  NaN                    NaN
# 2                   NaN                  NaN                    NaN
# 3                   NaN                  NaN                    NaN
# 4                   NaN                  NaN                    NaN
#
#   third_party_equals_covered_recipient_indicator  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   third_party_payment_recipient_indicator total_amount_of_payment_usdollars
# 0                  No Third Party Payment                             35.30
# 1                  No Third Party Payment                             10.14
# 2                  No Third Party Payment                              2.12
# 3                  No Third Party Payment                             22.61
# 4                  No Third Party Payment                             11.75
#
# [5 rows x 62 columns]

# %%
df['covered_recipient_type'].unique()
# Out:
# array(['Covered Recipient Physician',
#        'Covered Recipient Teaching Hospital'], dtype=object)

# %%
#Physician Profile Data
df_phy = pd.read_json("https://openpaymentsdata.cms.gov/resource/2maf-rx69.json")
print(df_phy.shape,df.shape)
df_phy.head()
# Out:
# (1000, 26) (1000, 62)
#   physician_profile_address_line_1 physician_profile_address_line_2  \
# 0          975 BAPTIST WAY STE 201                              NaN
# 1                  2055 READING RD                        SUITE 330
# 2                   622 W 168TH ST                              NaN
# 3              605 OLD NORCROSS RD                              NaN
# 4                   2213 CHERRY ST                              NaN
#
#   physician_profile_alternate_first_name  \
# 0                                    NaN
# 1                              FAIZUDDIN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   physician_profile_alternate_last_name  \
# 0                                   NaN
# 1                                 KHAJA
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   physician_profile_alternate_middle_name physician_profile_alternate_suffix  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
#
#   physician_profile_city physician_profile_country_name  \
# 0              HOMESTEAD                  UNITED STATES
# 1             CINCINNATI                  UNITED STATES
# 2               NEW YORK                  UNITED STATES
# 3          LAWRENCEVILLE                  UNITED STATES
# 4                 TOLEDO                  UNITED STATES
#
#   physician_profile_first_name  physician_profile_id  \
# 0                       GEORGE                763250
# 1                    FAIZUDDIN                 47799
# 2                      CHARLES               1132070
# 3                       Piyush                287913
# 4                        DAVID               2785803
#
#              ...            physician_profile_middle_name  \
# 0            ...                                        R
# 1            ...                                        M
# 2            ...                                        D
# 3            ...                                      NaN
# 4            ...                                      NaN
#
#   physician_profile_ops_taxonomy_1 physician_profile_ops_taxonomy_2  \
# 0                       208600000X                              NaN
# 1                       207WX0107X                       207W00000X
# 2                       207R00000X                              NaN
# 3                       207RN0300X                       208D00000X
# 4                       208D00000X                              NaN
#
#   physician_profile_ops_taxonomy_3 physician_profile_ops_taxonomy_4  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                       207Q00000X                       207R00000X
# 4                              NaN                              NaN
#
#   physician_profile_ops_taxonomy_5  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#                  physician_profile_primary_specialty physician_profile_state  \
# 0        Allopathic & Osteopathic Physicians|Surgery                      FL
# 1  Allopathic & Osteopathic Physicians|Ophthalmology                      OH
# 2  Allopathic & Osteopathic Physicians|Internal M...                      NY
# 3                                                NaN                      GA
# 4                                                NaN                      OH
#
#   physician_profile_suffix physician_profile_zipcode
# 0                      NaN                33033-7600
# 1                      NaN                45202-1461
# 2                      NaN                10032-3720
# 3                      NaN                30046-4315
# 4                      NaN                43608-2603
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Complete 2017 Program Year Open Payments Dataset
# A complete set of all data from the 2017 Program Year, which includes data reported about payments made from January 1 through December 31, 2017.

# %%
import requests, zipfile, io

#https://www.cms.gov/OpenPayments/Explore-the-Data/Dataset-Downloads.html
#Complete 2017 Program Year Open Payments Dataset
zip_file_url = 'http://download.cms.gov/openpayments/PGYR17_P062918.ZIP'
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall('./cms_data/2017_open_payments')

# %% [markdown]
# ### Physician Supplement File for all Program Years
# A supplementary file that displays all of the physicians indicated as recipients of payments in records reported in Open Payments. Each record includes the physicians demographic information, specialties, and license information, as well as a unique identification number (Physician Profile ID) that can be used to search for a specific physician in the general, research, and physician ownership files.

# %%
zip_file_url = 'http://download.cms.gov/openpayments/PHPRFL_P062918.ZIP'
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall('./cms_data/physician_supplement')
